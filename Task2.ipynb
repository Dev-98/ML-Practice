# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
data = pd.read_csv("data/task1/train.csv")

# Separate features and target
X = data.drop(columns=['target'])
y = data['target']

data.describe()
# Out:
#                  T1            T2            T3            T4            T5  \
# count  36752.000000  36752.000000  36752.000000  36752.000000  36752.000000
# mean     -65.865449    -64.521931    -64.574472    -65.296474    -64.462152
# std        8.737286      8.914559      8.154517      8.142803      8.068375
# min      -95.000000    -95.000000    -95.000000    -95.000000    -95.000000
# 25%      -72.000000    -70.000000    -70.000000    -70.000000    -69.000000
# 50%      -66.000000    -65.000000    -64.000000    -66.000000    -65.000000
# 75%      -61.000000    -59.000000    -59.000000    -61.000000    -59.000000
# max      -41.000000    -37.000000    -41.000000    -39.000000    -36.000000
#
#                  T6            T7            T8            T9           T10  \
# count  36752.000000  36752.000000  36752.000000  36752.000000  36752.000000
# mean     -63.318731    -67.030202    -66.591260    -65.692479    -65.555181
# ...

# %% [markdown]
# ## Clustering Kmeans model

# %%
X_scaled = StandardScaler().fit_transform(X)

# Determine the number of clusters using the Elbow method
wcss = []
for i in range(20, 40):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
# Plot the Elbow method
plt.figure(figsize=(10, 6))
plt.plot(range(20, 40), wcss, marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.title('Elbow Method for Determining Optimal Number of Clusters')
plt.show()

# %%
kmodel = KMeans(n_clusters = 30, random_state=42).fit(X_scaled)

# %%
# Predict cluster labels
labels = kmeans.predict(X_scaled)

# Add the cluster labels to the original data
data['Cluster'] = labels

# Evaluate the clustering with the silhouette score
silhouette_avg = silhouette_score(X_scaled, labels)
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: 0.21380006303446256

# %%
# Visualize the clusters (for the first two features)
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_scaled[:, 8], y=X_scaled[:, 9], hue=labels, palette='viridis')
plt.title('K-Means Clustering')
plt.xlabel('T8')
plt.ylabel('T9')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# ## Classification Model
